# %%
#import required modules
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("dataset.csv")
df
# Out:
#                  timestamp  vehicle_gps_latitude  vehicle_gps_longitude  \
# 0      2021-01-01 00:00:00             40.375568             -77.014318
# 1      2021-01-01 01:00:00             33.507818            -117.036902
# 2      2021-01-01 02:00:00             30.020640             -75.269224
# 3      2021-01-01 03:00:00             36.649223             -70.190529
# 4      2021-01-01 04:00:00             30.001279             -70.012195
# ...                    ...                   ...                    ...
# 32060  2024-08-28 20:00:00             48.496665            -104.031158
# 32061  2024-08-28 21:00:00             34.670137             -89.893091
# 32062  2024-08-28 22:00:00             42.963338             -82.149873
# 32063  2024-08-28 23:00:00             32.082410             -70.070154
# 32064  2024-08-29 00:00:00             38.576482             -94.579542
#
#        fuel_consumption_rate  eta_variation_hours  traffic_congestion_level  \
# 0                   5.136512             4.998009                  5.927586
# 1                   5.101512             0.984929                  1.591992
# 2                   5.090803             4.972665                  8.787765
# 3                   8.219558             3.095064                  0.045257
# 4                   5.000075             3.216077                  8.004851
# ...                      ...                  ...                       ...
# 32060               5.421806             4.394370                  0.192421
# 32061              10.624778             2.700635                  8.736143
# 32062               5.071596             0.485288                  7.420200
# 32063               5.000000             4.759411                  0.932050
# 32064               5.000046             4.068440                  7.156608
#
#        warehouse_inventory_level  loading_unloading_time  \
# 0                     985.716862                4.951392
# 1                     396.700206                1.030379
# 2                     832.408935                4.220229
# 3                       0.573283                0.530186
# 4                     914.925067                3.620890
# ...                          ...                     ...
# 32060                 127.684977                3.607803
# 32061                  84.638889                1.218165
# 32062                  48.500920                4.999149
# 32063                 972.437425                0.505242
# 32064                  16.669708                2.207746
#
#        handling_equipment_availability  order_fulfillment_status  ...  \
# 0                             0.481294                  0.761166  ...
# 1                             0.620780                  0.196594  ...
# 2                             0.810933                  0.152742  ...
# 3                             0.008525                  0.811885  ...
# 4                             0.020083                  0.053659  ...
# ...                                ...                       ...  ...
# 32060                         0.208643                  0.992997  ...
# 32061                         0.472389                  0.946031  ...
# 32062                         0.064366                  0.437687  ...
# 32063                         0.250949                  0.517051  ...
# 32064                         0.486014                  0.985761  ...
#
#        iot_temperature  cargo_condition_status  route_risk_level  \
# 0             0.574400                0.777263          1.182116
# 1            -9.753493                0.091839          9.611988
# 2            -6.491034                0.253529          6.570431
# 3            -0.151276                0.877576          0.548952
# 4             2.429448                0.262081          8.861443
# ...                ...                     ...               ...
# 32060        -8.835069                0.199377          9.893402
# 32061        -2.517654                0.673775          0.854378
# 32062        29.410878                0.949644          4.480552
# 32063        -6.951137                0.407377          9.185549
# 32064        18.796515                0.876529          2.112655
#
#        customs_clearance_time  driver_behavior_score  \
# 0                    0.502006               0.033843
# 1                    0.966774               0.201725
# 2                    0.945627               0.264045
# 3                    4.674035               0.362885
# 4                    3.445429               0.016957
# ...                       ...                    ...
# 32060                0.966050               0.109571
# 32061                1.665889               0.530289
# 32062                0.690990               0.537100
# 32063                4.462204               0.012896
# 32064                2.118384               0.974045
#
#        fatigue_monitoring_score  disruption_likelihood_score  \
# 0                      0.978599                     0.506152
# 1                      0.918586                     0.980784
# 2                      0.394215                     0.998633
# 3                      0.905444                     0.993320
# 4                      0.258702                     0.912433
# ...                         ...                          ...
# 32060                  0.511074                     0.953467
# 32061                  0.868418                     0.995329
# 32062                  0.896798                     0.442299
# 32063                  0.463018                     0.999999
# 32064                  0.759489                     0.996928
#
#        delay_probability  risk_classification  delivery_time_deviation
# 0               0.885291        Moderate Risk                 9.110682
# 1               0.544178            High Risk                 8.175281
# 2               0.803322            High Risk                 1.283594
# 3               0.025977            High Risk                 9.304897
# 4               0.991122            High Risk                 7.752484
# ...                  ...                  ...                      ...
# 32060           0.916745            High Risk                 5.506049
# 32061           0.808963            High Risk                -1.876938
# 32062           0.959197        Moderate Risk                 9.790219
# 32063           0.557340            High Risk                 9.956879
# 32064           0.999230            High Risk                 2.099656
#
# [32065 rows x 26 columns]

# %%
#to check if there is any na values 
df.isna().any().any()
# Out:
# False

# %%
# Get the dimensions of the dataframe (rows, columns)
print("\nDataset Shape:")
print(df.shape)
# Out:
# Dataset Shape:
# (32065, 26)

# %%
# Get the column names
print("\nColumn Names:")
print(df.columns)
# Out:
# Column Names:
# Index(['timestamp', 'vehicle_gps_latitude', 'vehicle_gps_longitude',
#        'fuel_consumption_rate', 'eta_variation_hours',
#        'traffic_congestion_level', 'warehouse_inventory_level',
#        'loading_unloading_time', 'handling_equipment_availability',
#        'order_fulfillment_status', 'weather_condition_severity',
#        'port_congestion_level', 'shipping_costs', 'supplier_reliability_score',
#        'lead_time_days', 'historical_demand', 'iot_temperature',
#        'cargo_condition_status', 'route_risk_level', 'customs_clearance_time',
#        'driver_behavior_score', 'fatigue_monitoring_score',
#        'disruption_likelihood_score', 'delay_probability',
#        'risk_classification', 'delivery_time_deviation'],
#       dtype='object')

# %%
# Get a summary of the dataframe, including data types and non-null counts
print("Dataframe Info:")
df.info()
# Out:
# Dataframe Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32065 entries, 0 to 32064
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   timestamp                        32065 non-null  object
#  1   vehicle_gps_latitude             32065 non-null  float64
#  2   vehicle_gps_longitude            32065 non-null  float64
#  3   fuel_consumption_rate            32065 non-null  float64
#  4   eta_variation_hours              32065 non-null  float64
#  5   traffic_congestion_level         32065 non-null  float64
#  6   warehouse_inventory_level        32065 non-null  float64
#  7   loading_unloading_time           32065 non-null  float64
#  8   handling_equipment_availability  32065 non-null  float64
#  9   order_fulfillment_status         32065 non-null  float64
#  10  weather_condition_severity       32065 non-null  float64
#  11  port_congestion_level            32065 non-null  float64
#  12  shipping_costs                   32065 non-null  float64
#  13  supplier_reliability_score       32065 non-null  float64
#  14  lead_time_days                   32065 non-null  float64
#  15  historical_demand                32065 non-null  float64
#  16  iot_temperature                  32065 non-null  float64
#  17  cargo_condition_status           32065 non-null  float64
#  18  route_risk_level                 32065 non-null  float64
#  19  customs_clearance_time           32065 non-null  float64
#  20  driver_behavior_score            32065 non-null  float64
#  21  fatigue_monitoring_score         32065 non-null  float64
#  22  disruption_likelihood_score      32065 non-null  float64
#  23  delay_probability                32065 non-null  float64
#  24  risk_classification              32065 non-null  object
#  25  delivery_time_deviation          32065 non-null  float64
# dtypes: float64(24), object(2)
# memory usage: 6.4+ MB

# %%
# Get descriptive statistics for all numerical columns
print("Descriptive Statistics:")
print(df.describe())
# Out:
# Descriptive Statistics:
#        vehicle_gps_latitude  vehicle_gps_longitude  fuel_consumption_rate  \
# count          32065.000000           32065.000000           32065.000000
# mean              38.023589             -90.116648               8.011735
# std                6.917909              17.369244               4.264960
# min               30.000000            -119.999998               5.000000
# 25%               31.280550            -106.253913               5.019984
# 50%               36.413820             -86.293414               5.636036
# 75%               44.453655             -73.079367               9.669944
# max               50.000000             -70.000000              19.999875
#
#        eta_variation_hours  traffic_congestion_level  \
# count         32065.000000              3.206500e+04
# mean              2.893068              4.991493e+00
# std               2.274044              3.532048e+00
# min              -1.999993              1.091633e-09
# 25%               1.185744              1.474720e+00
# 50%               3.882059              4.981244e+00
# 75%               4.884355              8.534902e+00
# max               5.000000              9.999999e+00
#
#        warehouse_inventory_level  loading_unloading_time  \
# count               3.206500e+04            32065.000000
# mean                2.992547e+02                2.291669
# std                 3.234435e+02                1.554202
# min                 1.322210e-12                0.500000
# 25%                 1.605163e+01                0.774798
# 50%                 1.572880e+02                1.917121
# 75%                 5.405980e+02                3.734188
# max                 9.999993e+02                5.000000
#
#        handling_equipment_availability  order_fulfillment_status  \
# count                     3.206500e+04              32065.000000
# mean                      3.026954e-01                  0.600740
# std                       3.259146e-01                  0.345672
# min                       4.565769e-16                  0.000001
# 25%                       1.710828e-02                  0.277096
# 50%                       1.595151e-01                  0.680553
# 75%                       5.535954e-01                  0.938160
# max                       9.999995e-01                  1.000000
#
#        weather_condition_severity  ...  historical_demand  iot_temperature  \
# count                3.206500e+04  ...       32065.000000     32065.000000
# mean                 4.976082e-01  ...        6022.001286         0.044792
# std                  3.532853e-01  ...        3427.638017        14.187486
# min                  4.536949e-09  ...         100.002966       -10.000000
# 25%                  1.440135e-01  ...        2822.607616        -9.931074
# 50%                  4.961781e-01  ...        6785.123209        -7.858681
# 75%                  8.498226e-01  ...        9374.252913         6.024012
# max                  1.000000e+00  ...       10000.000000        39.999886
#
#        cargo_condition_status  route_risk_level  customs_clearance_time  \
# count            3.206500e+04      32065.000000            32065.000000
# mean             2.972816e-01          7.001144                2.296448
# std              3.216115e-01          3.236328                1.555932
# min              7.255415e-19          0.000050                0.500000
# 25%              1.678269e-02          4.593407                0.776166
# 50%              1.549760e-01          8.385605                1.938273
# 75%              5.405408e-01          9.836152                3.750817
# max              1.000000e+00         10.000000                5.000000
#
#        driver_behavior_score  fatigue_monitoring_score  \
# count           3.206500e+04              3.206500e+04
# mean            4.983913e-01              6.008723e-01
# std             3.541589e-01              3.458101e-01
# min             4.043927e-09              3.269508e-07
# 25%             1.443567e-01              2.783148e-01
# 50%             4.988468e-01              6.831130e-01
# 75%             8.510762e-01              9.372889e-01
# max             1.000000e+00              1.000000e+00
#
#        disruption_likelihood_score  delay_probability  delivery_time_deviation
# count                 32065.000000       32065.000000             32065.000000
# mean                      0.803656           0.699077                 5.177648
# std                       0.279185           0.324514                 4.157988
# min                       0.000048           0.000003                -1.999998
# 25%                       0.693739           0.456009                 1.269197
# 50%                       0.958128           0.839599                 6.113662
# 75%                       0.998746           0.982391                 9.249206
# max                       1.000000           1.000000                10.000000
#
# [8 rows x 24 columns]

# %%
#summarizing missing values
missing_values = df.isnull().sum()
display(missing_values)
# Out:
# timestamp                          0
# vehicle_gps_latitude               0
# vehicle_gps_longitude              0
# fuel_consumption_rate              0
# eta_variation_hours                0
# traffic_congestion_level           0
# warehouse_inventory_level          0
# loading_unloading_time             0
# handling_equipment_availability    0
# order_fulfillment_status           0
# weather_condition_severity         0
# port_congestion_level              0
# shipping_costs                     0
# supplier_reliability_score         0
# lead_time_days                     0
# historical_demand                  0
# iot_temperature                    0
# cargo_condition_status             0
# route_risk_level                   0
# customs_clearance_time             0
# driver_behavior_score              0
# fatigue_monitoring_score           0
# disruption_likelihood_score        0
# delay_probability                  0
# risk_classification                0
# delivery_time_deviation            0
# dtype: int64

# %%
#check for the coloumns which have outliers 
numerical_cols = df.select_dtypes(include=np.number).columns
display(numerical_cols)
# Out:
# Index(['vehicle_gps_latitude', 'vehicle_gps_longitude',
#        'fuel_consumption_rate', 'eta_variation_hours',
#        'traffic_congestion_level', 'warehouse_inventory_level',
#        'loading_unloading_time', 'handling_equipment_availability',
#        'order_fulfillment_status', 'weather_condition_severity',
#        'port_congestion_level', 'shipping_costs', 'supplier_reliability_score',
#        'lead_time_days', 'historical_demand', 'iot_temperature',
#        'cargo_condition_status', 'route_risk_level', 'customs_clearance_time',
#        'driver_behavior_score', 'fatigue_monitoring_score',
#        'disruption_likelihood_score', 'delay_probability',
#        'delivery_time_deviation'],
#       dtype='object')

# %%
#calculating the outliers
print("--- Outlier Report ---")

# 2. Loop through each numerical column
for col in numerical_cols:
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    
    # Calculate the Interquartile Range (IQR)
    IQR = Q3 - Q1
    
    # Define the outlier boundaries 
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # 3. Find the data points that are considered outliers
    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    
    # 4. Print the results
    if not outliers.empty:
        print(f"Column '{col}': Found {len(outliers)} outliers.")
    else:
        print(f"Column '{col}': No outliers found.")
# Out:
# --- Outlier Report ---
# Column 'vehicle_gps_latitude': No outliers found.
# Column 'vehicle_gps_longitude': No outliers found.
# Column 'fuel_consumption_rate': Found 2536 outliers.
# Column 'eta_variation_hours': No outliers found.
# Column 'traffic_congestion_level': No outliers found.
# Column 'warehouse_inventory_level': No outliers found.
# Column 'loading_unloading_time': No outliers found.
# Column 'handling_equipment_availability': No outliers found.
# Column 'order_fulfillment_status': No outliers found.
# Column 'weather_condition_severity': No outliers found.
# Column 'port_congestion_level': No outliers found.
# Column 'shipping_costs': No outliers found.
# Column 'supplier_reliability_score': No outliers found.
# Column 'lead_time_days': No outliers found.
# Column 'historical_demand': No outliers found.
# Column 'iot_temperature': Found 2301 outliers.
# Column 'cargo_condition_status': No outliers found.
# Column 'route_risk_level': No outliers found.
# Column 'customs_clearance_time': No outliers found.
# Column 'driver_behavior_score': No outliers found.
# Column 'fatigue_monitoring_score': No outliers found.
# Column 'disruption_likelihood_score': Found 2494 outliers.
# Column 'delay_probability': No outliers found.
# Column 'delivery_time_deviation': No outliers found.

# %%
#columns with outliers > 0
columns_to_plot = [
    'fuel_consumption_rate',
    'iot_temperature',
    'disruption_likelihood_score'
]

sns.set_style("whitegrid")

# Create a figure to hold the plots
plt.figure(figsize=(18, 7))

# Generate a boxplot for each column
for i, col in enumerate(columns_to_plot, 1):
    plt.subplot(1, 3, i) # Create a 1x3 grid of plots
    sns.boxplot(y=df[col]) # Create a vertical boxplot
    plt.title(f'Box Plot of {col}', fontsize=14)
    plt.ylabel('Value')

plt.tight_layout()
plt.show()

# %%
#check for timestamps
df['timestamp_dt'] = pd.to_datetime(df['timestamp'])

# Check the date range
min_date = df['timestamp_dt'].min()
max_date = df['timestamp_dt'].max()

print(f"Earliest timestamp: {min_date}")
print(f"Latest timestamp:   {max_date}")
# Out:
# Earliest timestamp: 2021-01-01 00:00:00
# Latest timestamp:   2024-08-29 00:00:00

# %%
#finding the corealtion using a heatmap
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# 2. Calculate the correlation matrix
correlation_matrix = numerical_df.corr()

# 3. Set up and draw the heatmap
plt.figure(figsize=(20, 16))
sns.heatmap(correlation_matrix, cmap='coolwarm')
plt.title('Correlation Matrix of Numerical Features', fontsize=16)

# 4. Show the plot
plt.show()

# %%
#finding correlation using a table 
# 1. Select only the numerical columns
numerical_df = df.select_dtypes(include=['float64', 'int64'])

# 2. Calculate the correlation matrix
correlation_matrix = numerical_df.corr()

# 3. Print the resulting table
print("--- Correlation Matrix Table ---")
print(correlation_matrix)
# Out:
# --- Correlation Matrix Table ---
#                                  vehicle_gps_latitude  vehicle_gps_longitude  \
# vehicle_gps_latitude                         1.000000               0.006575
# vehicle_gps_longitude                        0.006575               1.000000
# fuel_consumption_rate                       -0.002051              -0.002578
# eta_variation_hours                          0.002856               0.004960
# traffic_congestion_level                    -0.000294              -0.010364
# warehouse_inventory_level                    0.002568              -0.003587
# loading_unloading_time                       0.003429              -0.006421
# handling_equipment_availability             -0.003693              -0.002189
# order_fulfillment_status                     0.005628               0.001460
# weather_condition_severity                   0.006376               0.005315
# port_congestion_level                       -0.009577              -0.004752
# shipping_costs                              -0.006088               0.006964
# supplier_reliability_score                  -0.005095               0.004586
# lead_time_days                              -0.005251               0.002514
# historical_demand                            0.004596              -0.008845
# iot_temperature                             -0.001336               0.007927
# cargo_condition_status                      -0.002211               0.003344
# route_risk_level                            -0.012222               0.003614
# customs_clearance_time                       0.004441              -0.003795
# driver_behavior_score                       -0.006078              -0.006184
# fatigue_monitoring_score                    -0.008915               0.002398
# disruption_likelihood_score                 -0.006788               0.000800
# delay_probability                           -0.006185              -0.005691
# delivery_time_deviation                      0.000416              -0.001639
#
#                                  fuel_consumption_rate  eta_variation_hours  \
# vehicle_gps_latitude                         -0.002051             0.002856
# vehicle_gps_longitude                        -0.002578             0.004960
# fuel_consumption_rate                         1.000000             0.004064
# eta_variation_hours                           0.004064             1.000000
# traffic_congestion_level                      0.005028            -0.004911
# warehouse_inventory_level                     0.004062             0.002014
# loading_unloading_time                        0.004735            -0.003600
# handling_equipment_availability               0.005117            -0.002190
# order_fulfillment_status                     -0.001407            -0.005203
# weather_condition_severity                   -0.008411             0.006269
# port_congestion_level                         0.002799            -0.003873
# shipping_costs                                0.005036            -0.002224
# supplier_reliability_score                    0.005896             0.007855
# lead_time_days                               -0.012604            -0.005142
# historical_demand                            -0.002226             0.005310
# iot_temperature                               0.007470            -0.004108
# cargo_condition_status                        0.004966             0.001605
# route_risk_level                              0.009829            -0.005808
# customs_clearance_time                        0.002723            -0.003210
# driver_behavior_score                        -0.001414             0.002218
# fatigue_monitoring_score                     -0.001881             0.006951
# disruption_likelihood_score                   0.002300             0.004189
# delay_probability                            -0.013655            -0.006897
# delivery_time_deviation                       0.012495            -0.000746
#
#                                  traffic_congestion_level  \
# vehicle_gps_latitude                            -0.000294
# vehicle_gps_longitude                           -0.010364
# fuel_consumption_rate                            0.005028
# eta_variation_hours                             -0.004911
# traffic_congestion_level                         1.000000
# warehouse_inventory_level                        0.009780
# loading_unloading_time                          -0.014678
# handling_equipment_availability                 -0.001337
# order_fulfillment_status                        -0.001370
# weather_condition_severity                       0.000698
# port_congestion_level                           -0.006929
# shipping_costs                                  -0.000031
# supplier_reliability_score                       0.007166
# lead_time_days                                  -0.003040
# historical_demand                                0.001981
# iot_temperature                                  0.006053
# cargo_condition_status                          -0.004870
# route_risk_level                                 0.006400
# customs_clearance_time                          -0.003108
# driver_behavior_score                           -0.000264
# fatigue_monitoring_score                         0.010069
# disruption_likelihood_score                      0.000145
# delay_probability                               -0.003790
# delivery_time_deviation                          0.000510
#
#                                  warehouse_inventory_level  \
# vehicle_gps_latitude                              0.002568
# vehicle_gps_longitude                            -0.003587
# fuel_consumption_rate                             0.004062
# eta_variation_hours                               0.002014
# traffic_congestion_level                          0.009780
# warehouse_inventory_level                         1.000000
# loading_unloading_time                            0.000579
# handling_equipment_availability                  -0.005307
# order_fulfillment_status                         -0.005007
# weather_condition_severity                       -0.011976
# port_congestion_level                             0.005260
# shipping_costs                                   -0.005494
# supplier_reliability_score                       -0.004991
# lead_time_days                                    0.011781
# historical_demand                                 0.004388
# iot_temperature                                   0.004088
# cargo_condition_status                            0.003896
# route_risk_level                                  0.004514
# customs_clearance_time                           -0.005500
# driver_behavior_score                             0.002880
# fatigue_monitoring_score                         -0.010713
# disruption_likelihood_score                      -0.013536
# delay_probability                                 0.004686
# delivery_time_deviation                          -0.007463
#
#                                  loading_unloading_time  \
# vehicle_gps_latitude                           0.003429
# vehicle_gps_longitude                         -0.006421
# fuel_consumption_rate                          0.004735
# eta_variation_hours                           -0.003600
# traffic_congestion_level                      -0.014678
# warehouse_inventory_level                      0.000579
# loading_unloading_time                         1.000000
# handling_equipment_availability                0.007973
# order_fulfillment_status                       0.003916
# weather_condition_severity                     0.003824
# port_congestion_level                          0.002283
# shipping_costs                                 0.003086
# supplier_reliability_score                     0.009561
# lead_time_days                                -0.003915
# historical_demand                             -0.006478
# iot_temperature                                0.003213
# cargo_condition_status                        -0.000013
# route_risk_level                              -0.002197
# customs_clearance_time                         0.007377
# driver_behavior_score                         -0.001725
# fatigue_monitoring_score                       0.001803
# disruption_likelihood_score                    0.002918
# delay_probability                             -0.000706
# delivery_time_deviation                        0.003375
#
#                                  handling_equipment_availability  \
# vehicle_gps_latitude                                   -0.003693
# vehicle_gps_longitude                                  -0.002189
# fuel_consumption_rate                                   0.005117
# eta_variation_hours                                    -0.002190
# traffic_congestion_level                               -0.001337
# warehouse_inventory_level                              -0.005307
# loading_unloading_time                                  0.007973
# handling_equipment_availability                         1.000000
# order_fulfillment_status                               -0.004546
# weather_condition_severity                              0.001767
# port_congestion_level                                  -0.008884
# shipping_costs                                         -0.009576
# supplier_reliability_score                              0.001763
# lead_time_days                                          0.001856
# historical_demand                                      -0.002886
# iot_temperature                                        -0.006315
# cargo_condition_status                                 -0.004692
# route_risk_level                                       -0.001362
# customs_clearance_time                                 -0.006250
# driver_behavior_score                                   0.005388
# fatigue_monitoring_score                               -0.007865
# disruption_likelihood_score                             0.004005
# delay_probability                                       0.002690
# delivery_time_deviation                                -0.004639
#
#                                  order_fulfillment_status  \
# vehicle_gps_latitude                             0.005628
# vehicle_gps_longitude                            0.001460
# fuel_consumption_rate                           -0.001407
# eta_variation_hours                             -0.005203
# traffic_congestion_level                        -0.001370
# warehouse_inventory_level                       -0.005007
# loading_unloading_time                           0.003916
# handling_equipment_availability                 -0.004546
# order_fulfillment_status                         1.000000
# weather_condition_severity                       0.004263
# port_congestion_level                            0.001292
# shipping_costs                                   0.001751
# supplier_reliability_score                       0.004483
# lead_time_days                                   0.008570
# historical_demand                                0.003702
# iot_temperature                                  0.001685
# cargo_condition_status                           0.007163
# route_risk_level                                 0.002856
# customs_clearance_time                          -0.010632
# driver_behavior_score                            0.001984
# fatigue_monitoring_score                        -0.000563
# disruption_likelihood_score                     -0.008310
# delay_probability                                0.009730
# delivery_time_deviation                          0.003329
#
#                                  weather_condition_severity  ...  \
# vehicle_gps_latitude                               0.006376  ...
# vehicle_gps_longitude                              0.005315  ...
# fuel_consumption_rate                             -0.008411  ...
# eta_variation_hours                                0.006269  ...
# traffic_congestion_level                           0.000698  ...
# warehouse_inventory_level                         -0.011976  ...
# loading_unloading_time                             0.003824  ...
# handling_equipment_availability                    0.001767  ...
# order_fulfillment_status                           0.004263  ...
# weather_condition_severity                         1.000000  ...
# port_congestion_level                             -0.001391  ...
# shipping_costs                                    -0.006651  ...
# supplier_reliability_score                        -0.002365  ...
# lead_time_days                                     0.000499  ...
# historical_demand                                 -0.007898  ...
# iot_temperature                                    0.003168  ...
# cargo_condition_status                            -0.001930  ...
# route_risk_level                                  -0.006182  ...
# customs_clearance_time                             0.000040  ...
# driver_behavior_score                             -0.009517  ...
# fatigue_monitoring_score                           0.002781  ...
# disruption_likelihood_score                       -0.000749  ...
# delay_probability                                  0.001503  ...
# delivery_time_deviation                           -0.000541  ...
#
#                                  historical_demand  iot_temperature  \
# vehicle_gps_latitude                      0.004596        -0.001336
# vehicle_gps_longitude                    -0.008845         0.007927
# fuel_consumption_rate                    -0.002226         0.007470
# eta_variation_hours                       0.005310        -0.004108
# traffic_congestion_level                  0.001981         0.006053
# warehouse_inventory_level                 0.004388         0.004088
# loading_unloading_time                   -0.006478         0.003213
# handling_equipment_availability          -0.002886        -0.006315
# order_fulfillment_status                  0.003702         0.001685
# weather_condition_severity               -0.007898         0.003168
# port_congestion_level                     0.002693        -0.006458
# shipping_costs                            0.000241        -0.003140
# supplier_reliability_score                0.000832        -0.002079
# lead_time_days                           -0.000449        -0.000964
# historical_demand                         1.000000        -0.007213
# iot_temperature                          -0.007213         1.000000
# cargo_condition_status                    0.000759        -0.001418
# route_risk_level                          0.003171        -0.002086
# customs_clearance_time                   -0.001856         0.004658
# driver_behavior_score                    -0.009136         0.003118
# fatigue_monitoring_score                 -0.001704        -0.004621
# disruption_likelihood_score               0.001754        -0.003729
# delay_probability                        -0.002907        -0.001139
# delivery_time_deviation                   0.000615        -0.000569
#
#                                  cargo_condition_status  route_risk_level  \
# vehicle_gps_latitude                          -0.002211         -0.012222
# vehicle_gps_longitude                          0.003344          0.003614
# fuel_consumption_rate                          0.004966          0.009829
# eta_variation_hours                            0.001605         -0.005808
# traffic_congestion_level                      -0.004870          0.006400
# warehouse_inventory_level                      0.003896          0.004514
# loading_unloading_time                        -0.000013         -0.002197
# handling_equipment_availability               -0.004692         -0.001362
# order_fulfillment_status                       0.007163          0.002856
# weather_condition_severity                    -0.001930         -0.006182
# port_congestion_level                          0.004251          0.008034
# shipping_costs                                 0.002577          0.005380
# supplier_reliability_score                    -0.006531          0.010123
# lead_time_days                                -0.003453         -0.009045
# historical_demand                              0.000759          0.003171
# iot_temperature                               -0.001418         -0.002086
# cargo_condition_status                         1.000000         -0.001253
# route_risk_level                              -0.001253          1.000000
# customs_clearance_time                        -0.003396         -0.003696
# driver_behavior_score                          0.002222         -0.000707
# fatigue_monitoring_score                      -0.011145          0.004024
# disruption_likelihood_score                    0.007495          0.006345
# delay_probability                              0.002910         -0.003407
# delivery_time_deviation                       -0.001348         -0.000076
#
#                                  customs_clearance_time  \
# vehicle_gps_latitude                           0.004441
# vehicle_gps_longitude                         -0.003795
# fuel_consumption_rate                          0.002723
# eta_variation_hours                           -0.003210
# traffic_congestion_level                      -0.003108
# warehouse_inventory_level                     -0.005500
# loading_unloading_time                         0.007377
# handling_equipment_availability               -0.006250
# order_fulfillment_status                      -0.010632
# weather_condition_severity                     0.000040
# port_congestion_level                          0.005088
# shipping_costs                                -0.000841
# supplier_reliability_score                    -0.001121
# lead_time_days                                -0.002807
# historical_demand                             -0.001856
# iot_temperature                                0.004658
# cargo_condition_status                        -0.003396
# route_risk_level                              -0.003696
# customs_clearance_time                         1.000000
# driver_behavior_score                         -0.001498
# fatigue_monitoring_score                      -0.006761
# disruption_likelihood_score                   -0.000113
# delay_probability                              0.004896
# delivery_time_deviation                       -0.009244
#
#                                  driver_behavior_score  \
# vehicle_gps_latitude                         -0.006078
# vehicle_gps_longitude                        -0.006184
# fuel_consumption_rate                        -0.001414
# eta_variation_hours                           0.002218
# traffic_congestion_level                     -0.000264
# warehouse_inventory_level                     0.002880
# loading_unloading_time                       -0.001725
# handling_equipment_availability               0.005388
# order_fulfillment_status                      0.001984
# weather_condition_severity                   -0.009517
# port_congestion_level                         0.001914
# shipping_costs                               -0.001449
# supplier_reliability_score                   -0.004466
# lead_time_days                               -0.014183
# historical_demand                            -0.009136
# iot_temperature                               0.003118
# cargo_condition_status                        0.002222
# route_risk_level                             -0.000707
# customs_clearance_time                       -0.001498
# driver_behavior_score                         1.000000
# fatigue_monitoring_score                      0.006931
# disruption_likelihood_score                   0.005556
# delay_probability                            -0.003919
# delivery_time_deviation                      -0.003969
#
#                                  fatigue_monitoring_score  \
# vehicle_gps_latitude                            -0.008915
# vehicle_gps_longitude                            0.002398
# fuel_consumption_rate                           -0.001881
# eta_variation_hours                              0.006951
# traffic_congestion_level                         0.010069
# warehouse_inventory_level                       -0.010713
# loading_unloading_time                           0.001803
# handling_equipment_availability                 -0.007865
# order_fulfillment_status                        -0.000563
# weather_condition_severity                       0.002781
# port_congestion_level                           -0.000530
# shipping_costs                                  -0.009667
# supplier_reliability_score                       0.000930
# lead_time_days                                   0.002529
# historical_demand                               -0.001704
# iot_temperature                                 -0.004621
# cargo_condition_status                          -0.011145
# route_risk_level                                 0.004024
# customs_clearance_time                          -0.006761
# driver_behavior_score                            0.006931
# fatigue_monitoring_score                         1.000000
# disruption_likelihood_score                      0.003248
# delay_probability                                0.001070
# delivery_time_deviation                          0.003491
#
#                                  disruption_likelihood_score  \
# vehicle_gps_latitude                               -0.006788
# vehicle_gps_longitude                               0.000800
# fuel_consumption_rate                               0.002300
# eta_variation_hours                                 0.004189
# traffic_congestion_level                            0.000145
# warehouse_inventory_level                          -0.013536
# loading_unloading_time                              0.002918
# handling_equipment_availability                     0.004005
# order_fulfillment_status                           -0.008310
# weather_condition_severity                         -0.000749
# port_congestion_level                               0.005405
# shipping_costs                                     -0.002374
# supplier_reliability_score                          0.001684
# lead_time_days                                      0.001555
# historical_demand                                   0.001754
# iot_temperature                                    -0.003729
# cargo_condition_status                              0.007495
# route_risk_level                                    0.006345
# customs_clearance_time                             -0.000113
# driver_behavior_score                               0.005556
# fatigue_monitoring_score                            0.003248
# disruption_likelihood_score                         1.000000
# delay_probability                                  -0.008175
# delivery_time_deviation                             0.002622
#
#                                  delay_probability  delivery_time_deviation
# vehicle_gps_latitude                     -0.006185                 0.000416
# vehicle_gps_longitude                    -0.005691                -0.001639
# fuel_consumption_rate                    -0.013655                 0.012495
# eta_variation_hours                      -0.006897                -0.000746
# traffic_congestion_level                 -0.003790                 0.000510
# warehouse_inventory_level                 0.004686                -0.007463
# loading_unloading_time                   -0.000706                 0.003375
# handling_equipment_availability           0.002690                -0.004639
# order_fulfillment_status                  0.009730                 0.003329
# weather_condition_severity                0.001503                -0.000541
# port_congestion_level                     0.008972                 0.010612
# shipping_costs                           -0.000280                 0.002504
# supplier_reliability_score                0.001890                 0.004384
# lead_time_days                            0.001083                -0.002460
# historical_demand                        -0.002907                 0.000615
# iot_temperature                          -0.001139                -0.000569
# cargo_condition_status                    0.002910                -0.001348
# route_risk_level                         -0.003407                -0.000076
# customs_clearance_time                    0.004896                -0.009244
# driver_behavior_score                    -0.003919                -0.003969
# fatigue_monitoring_score                  0.001070                 0.003491
# disruption_likelihood_score              -0.008175                 0.002622
# delay_probability                         1.000000                 0.005530
# delivery_time_deviation                   0.005530                 1.000000
#
# [24 rows x 24 columns]
